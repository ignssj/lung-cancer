# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
single_img = np.load('../data/Image/LIDC-IDRI-0078/0078_NI003_slice001.npy')

# %%
single_msk = np.load('../data/Mask/LIDC-IDRI-0078/0078_MA003_slice001.npy')

# %%
display_img = single_img*255

# %%
display_msk = single_msk*255

# %%
plt.imshow(display_img,cmap='gray')

# %%
plt.imshow(display_msk,cmap='gray')

# %%
display_total = display_img + display_msk

# %%
plt.imshow(display_total,cmap='gray')
